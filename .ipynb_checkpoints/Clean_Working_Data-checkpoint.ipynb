# %%
#import dependencies
import pandas as pd
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
import sklearn as skl
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-90b47dfa5fe8> in <module>
#       7 import numpy as np
#       8 import sklearn as skl
# ----> 9 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
#read in new csv's
mean_max__min_df = pd.read_csv('../Data/min_mean_max.csv')
mean_max__min_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491187 entries, 0 to 491186
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   491187 non-null  int64
#  1   Name         491187 non-null  object
#  2   CompanyName  491187 non-null  object
#  3   year         491187 non-null  int64
#  4   month        491187 non-null  int64
#  5   MeanClose    491187 non-null  float64
#  6   MinClose     491187 non-null  float64
#  7   MaxClose     491187 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 30.0+ MB

# %%
mean_max__min_df.round(decimals=3)
# Out:
#         Unnamed: 0  Name           CompanyName  year  month  MeanClose  \
# 0                0     A  Agilent Technologies  2011      1     30.288
# 1                1     A  Agilent Technologies  2011      2     30.709
# 2                2     A  Agilent Technologies  2011      3     31.516
# 3                3     A  Agilent Technologies  2011      4     33.625
# 4                4     A  Agilent Technologies  2011      5     35.959
# ...            ...   ...                   ...   ...    ...        ...
# 491182      491182  ZYXI                 Zynex  2021      4     15.517
# 491183      491183  ZYXI                 Zynex  2021      5     14.342
# 491184      491184  ZYXI                 Zynex  2021      6     15.710
# 491185      491185  ZYXI                 Zynex  2021      7     15.960
# 491186      491186  ZYXI                 Zynex  2021      8     14.246
#
#         MinClose  MaxClose
# 0         29.313    31.724
# 1         28.934    32.203
# 2         29.099    33.441
# 3         32.067    35.994
# 4         34.828    37.611
# ...          ...       ...
# 491182    14.770    16.360
# 491183    13.480    15.220
# 491184    15.010    16.100
# 491185    13.890    17.220
# 491186    12.960    14.920
#
# [491187 rows x 8 columns]
